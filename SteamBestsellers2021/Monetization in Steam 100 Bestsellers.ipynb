# %% [markdown]
# # Steam 100 Bestsellers Monetization Types
#
# ## Dataset
#
# Data for charts are based on GameDiscoverCo [dataset](https://docs.google.com/spreadsheets/d/1jbR6wVzDf_Y4d_GpDzFyWEi1Z1WyCCazmYF1Ahr5AAY/edit#gid=0).
#
# ## Notes
#
# 1. Game CAN have more then one type of monetization (IAP or DLC).
# 2. Standalone games are titile WITHOUT monetization.

# %% [markdown]
# ![monetization.png](attachment:monetization.png)

# %% [markdown]
# ![monetization_group.png](attachment:monetization_group.png)

# %% [markdown]
# ![premiers.png](attachment:premiers.png)
